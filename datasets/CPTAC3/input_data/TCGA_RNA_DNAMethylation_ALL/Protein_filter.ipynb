# %% [markdown]
# # Get the protein files for which we have matching DNA methylation and gene expression
#
# 1. ClearCellRenalCellCarcinoma_PDC000127
# 2. HeadandNeckSquamousCellCarcinoma_PDC000221
# 3. PancreaticDuctalAdenocarcinoma_PDC000270
# 4. LungSquamousCellCarcinoma_PDC000234
# 5. LungAdenocarcinoma_PDC000153
# 6. UterineCorpusEndometrialCarcinoma_PDC000125
#
# # Normalisation
#
# https://www.nature.com/articles/s41467-022-30342-3#MOESM11
# `For each study, taking the expression values provided in the associated data table, we normalized proteomic data for downstream analyses in the following manner and as previously described21,22. First, within each proteomic profile, we normalized logged expression values to standard deviations from the median. Next, we normalized expression values across samples to standard deviations from the median. Similarly, we separately normalized both total protein and phospho-protein datasets for a given cancer type and dataset. For datasets where two different data centers generated values on the same tumors, we averaged normalized values from the respective data centers in instances of duplicate profiles for the same tumor sample. As intended, by normalizing expression within each cancer type and within each proteomic dataset, neither tissue-dominant differences nor inter-laboratory batch effects would drive the downstream analysis results, including unsupervised subtype discovery. For the compendium dataset of total proteins, a total of 15,439 unique genes by Entrez Identifier were represented in at least one of the individual datasets. For the compendium dataset of phospho-proteins, a total of 199,284 phospho-proteins, involving 11,671 unique genes, were represented in at least one of the individual datasets. Of these phospho-proteins, 5419 had available data for >50% of samples in at least seven cancer types.`

# %%
cols
# Out:
# ['CPT0079430001 Log Ratio',
#  'CPT0023360001 Log Ratio',
#  'CPT0023350003 Log Ratio',
#  'CPT0079410003 Log Ratio',
#  'CPT0087040003 Log Ratio',
#  'CPT0077310003 Log Ratio',
#  'CPT0077320001 Log Ratio',
#  'CPT0087050003 Log Ratio',
#  'CPT0002270011 Log Ratio',
#  'CPT0078840001 Log Ratio',
#  'CPT0075570001 Log Ratio',
#  'CPT0075560003 Log Ratio',
#  'CPT0078830003 Log Ratio',
#  'CPT0077490003 Log Ratio',
#  'CPT0077500001 Log Ratio',
#  'CPT0023690003 Log Ratio',
#  'CPT0023710001 Log Ratio',
#  'CPT0025060001 Log Ratio',
#  'CPT0092290003 Log Ratio',
#  'CPT0014130001 Log Ratio',
#  'CPT0001230001 Log Ratio',
#  'CPT0071150004 Log Ratio',
#  'CPT0014160003 Log Ratio',
#  'CPT0092310003 Log Ratio',
#  'CPT0001220008 Log Ratio',
#  'CPT0025050003 Log Ratio',
#  'CPT0088500001 Log Ratio',
#  'CPT0078510003 Log Ratio',
#  'CPT0079510001 Log Ratio',
#  'CPT0089020003 Log Ratio',
#  'CPT0078530001 Log Ratio',
#  'CPT0079480003 Log Ratio',
#  'CPT0088480003 Log Ratio',
#  'CPT0089040001 Log Ratio',
#  'CPT0026410003 Log Ratio',
#  'CPT0006440003 Log Ratio',
#  'CPT0066470004 Log Ratio',
#  'CPT0066430001 Log Ratio',
#  'CPT0088970003 Log Ratio',
#  'CPT0020020001 Log Ratio',
#  'CPT0006530001 Log Ratio',
#  'CPT0026420001 Log Ratio',
#  'CPT0019990003 Log Ratio',
#  'CPT0000790001 Log Ratio',
#  'CPT0001550001 Log Ratio',
#  'CPT0065450001 Log Ratio',
#  'CPT0001540009 Log Ratio',
#  'CPT0066480003 Log Ratio',
#  'CPT0066520001 Log Ratio',
#  'CPT0065430003 Log Ratio',
#  'CPT0000780007 Log Ratio',
#  'CPT0019130003 Log Ratio',
#  'CPT0014350001 Log Ratio',
#  'CPT0079000001 Log Ratio',
#  'CPT0078990003 Log Ratio',
#  'CPT0000870016 Log Ratio',
#  'CPT0014370004 Log Ratio',
#  'CPT0019160001 Log Ratio',
#  'CPT0000890001 Log Ratio',
#  'CPT0065820001 Log Ratio',
#  'CPT0086360003 Log Ratio',
#  'CPT0092800003 Log Ratio',
#  'CPT0065810003 Log Ratio',
#  'CPT0092790003 Log Ratio',
#  'CPT0001500009 Log Ratio',
#  'CPT0086370003 Log Ratio',
#  'CPT0001510001 Log Ratio',
#  'CPT0006950001 Log Ratio',
#  'CPT0006900003 Log Ratio',
#  'CPT0010120001 Log Ratio',
#  'CPT0025610001 Log Ratio',
#  'CPT0081600003 Log Ratio',
#  'CPT0081620001 Log Ratio',
#  'CPT0025580004 Log Ratio',
#  'CPT0010110003 Log Ratio',
#  'CPT0001180009 Log Ratio',
#  'CPT0082010001 Log Ratio',
#  'CPT0015910003 Log Ratio',
#  'CPT0086870003 Log Ratio',
#  'CPT0063330001 Log Ratio',
#  'CPT0001190001 Log Ratio',
#  'CPT0063320003 Log Ratio',
#  'CPT0081990003 Log Ratio',
#  'CPT0086890003 Log Ratio',
#  'CPT0078660003 Log Ratio',
#  'CPT0001340003 Log Ratio',
#  'CPT0020130001 Log Ratio',
#  'CPT0075170001 Log Ratio',
#  'CPT0001350001 Log Ratio',
#  'CPT0078670001 Log Ratio',
#  'CPT0075130003 Log Ratio',
#  'CPT0020120003 Log Ratio',
#  'CPT0078930003 Log Ratio',
#  'CPT0089480003 Log Ratio',
#  'CPT0000640003 Log Ratio',
#  'CPT0078940001 Log Ratio',
#  'CPT0088630003 Log Ratio',
#  'CPT0089460004 Log Ratio',
#  'CPT0000660001 Log Ratio',
#  'CPT0088640003 Log Ratio',
#  'CPT0084560003 Log Ratio',
#  'CPT0084590001 Log Ratio',
#  'CPT0007470001 Log Ratio',
#  'CPT0065870003 Log Ratio',
#  'CPT0086830003 Log Ratio',
#  'CPT0069000003 Log Ratio',
#  'CPT0007320003 Log Ratio',
#  'CPT0086820003 Log Ratio',
#  'CPT0069010001 Log Ratio',
#  'CPT0002350011 Log Ratio',
#  'CPT0063640001 Log Ratio',
#  'CPT0088780001 Log Ratio',
#  'CPT0088760003 Log Ratio',
#  'CPT0088710001 Log Ratio',
#  'CPT0088690003 Log Ratio',
#  'CPT0002370001 Log Ratio',
#  'CPT0063630003 Log Ratio',
#  'CPT0064370003 Log Ratio',
#  'CPT0010170001 Log Ratio',
#  'CPT0064400001 Log Ratio',
#  'CPT0086970003 Log Ratio',
#  'CPT0092190003 Log Ratio',
#  'CPT0092160003 Log Ratio',
#  'CPT0010160003 Log Ratio',
#  'CPT0086950003 Log Ratio',
#  'CPT0088900003 Log Ratio',
#  'CPT0079270003 Log Ratio',
#  'CPT0088920001 Log Ratio',
#  'CPT0079300001 Log Ratio',
#  'CPT0088550004 Log Ratio',
#  'CPT0014450004 Log Ratio',
#  'CPT0088570001 Log Ratio',
#  'CPT0014470001 Log Ratio',
#  'CPT0006730001 Log Ratio',
#  'CPT0069190001 Log Ratio',
#  'CPT0092730003 Log Ratio',
#  'CPT0092740003 Log Ratio',
#  'CPT0006630003 Log Ratio',
#  'CPT0025920001 Log Ratio',
#  'CPT0025880003 Log Ratio',
#  'CPT0069160003 Log Ratio',
#  'CPT0007870001 Log Ratio',
#  'CPT0001270001 Log Ratio',
#  'CPT0077110003 Log Ratio',
#  'CPT0077140001 Log Ratio',
#  'CPT0001260009 Log Ratio',
#  'CPT0076350001 Log Ratio',
#  'CPT0076330003 Log Ratio',
#  'CPT0007860003 Log Ratio',
#  'CPT0079380003 Log Ratio',
#  'CPT0015810003 Log Ratio',
#  'CPT0086030003 Log Ratio',
#  'CPT0085670003 Log Ratio',
#  'CPT0025230003 Log Ratio',
#  'CPT0065750003 Log Ratio',
#  'CPT0015730003 Log Ratio',
#  'CPT0078800003 Log Ratio',
#  'CPT0079230003 Log Ratio',
#  'CPT0025170003 Log Ratio',
#  'CPT0025110003 Log Ratio',
#  'CPT0025290003 Log Ratio',
#  'CPT0081880003 Log Ratio',
#  'CPT0075720003 Log Ratio',
#  'CPT0065930003 Log Ratio',
#  'CPT0025350003 Log Ratio',
#  'CPT0065690003 Log Ratio',
#  'CPT0011410003 Log Ratio',
#  'CPT0024670003 Log Ratio',
#  'CPT0024680001 Log Ratio',
#  'CPT0012550003 Log Ratio',
#  'CPT0013790003 Log Ratio',
#  'CPT0012570003 Log Ratio',
#  'CPT0012770003 Log Ratio',
#  'CPT0012370003 Log Ratio',
#  'CPT0011240003 Log Ratio',
#  'CPT0079180003 Log Ratio',
#  'CPT0012640003 Log Ratio',
#  'CPT0012090003 Log Ratio',
#  'CPT0018250001 Log Ratio',
#  'CPT0012290003 Log Ratio',
#  'CPT0017850003 Log Ratio',
#  'CPT0012180003 Log Ratio',
#  'CPT0012280003 Log Ratio',
#  'CPT0012670003 Log Ratio',
#  'CPT0012080003 Log Ratio',
#  'CPT0021240003 Log Ratio',
#  'CPT0009020003 Log Ratio',
#  'CPT0017450001 Log Ratio',
#  'CPT0009060003 Log Ratio',
#  'CPT0012900004 Log Ratio',
#  'CPT0017410003 Log Ratio',
#  'CPT0009080003 Log Ratio',
#  'CPT0012920003 Log Ratio',
#  'CPT0009000003 Log Ratio']

# %%
sample_df
# Out:
#                                Aliquot ID Aliquot Submitter ID  \
# 0    bd34fbb3-2053-11e9-b7f8-0a80fada099c        CPT0026410003
# 1    6a6c6e30-2053-11e9-b7f8-0a80fada099c        CPT0002370001
# 2    4f9821f1-2053-11e9-b7f8-0a80fada099c        CPT0000790001
# 3    2ca7d56f-2054-11e9-b7f8-0a80fada099c                  QC5
# 4    a8451484-2053-11e9-b7f8-0a80fada099c        CPT0019130003
# ..                                    ...                  ...
# 203  b483c688-2053-11e9-b7f8-0a80fada099c        CPT0025060001
# 204  d471cfe4-2053-11e9-b7f8-0a80fada099c        CPT0075130003
# 205  48b575ca-2053-11e9-b7f8-0a80fada099c        CPT0000660001
# 206  2915e723-2054-11e9-b7f8-0a80fada099c                  QC1
# 207  fd90e5e8-2053-11e9-b7f8-0a80fada099c        CPT0086820003
#
#                                 Sample ID Sample Submitter ID  \
# 0    b72322c6-204c-11e9-b7f8-0a80fada099c        C3L-00791-01
# 1    89b29b3b-204c-11e9-b7f8-0a80fada099c        C3L-00360-06
# 2    7e25284f-204c-11e9-b7f8-0a80fada099c        C3L-00097-06
# 3    0abbe6ca-204e-11e9-b7f8-0a80fada099c                 QC5
# 4    a51fb8fe-204c-11e9-b7f8-0a80fada099c        C3L-00583-01
# ..                                    ...                 ...
# 203  ae645749-204c-11e9-b7f8-0a80fada099c        C3L-00607-02
# 204  c8988ee6-204d-11e9-b7f8-0a80fada099c        C3N-01200-02
# 205  8165afd5-204c-11e9-b7f8-0a80fada099c        C3L-00103-06
# 206  03394f84-204e-11e9-b7f8-0a80fada099c                 QC1
# 207  fbfa1f47-204c-11e9-b7f8-0a80fada099c        C3L-01313-03
#
#                                   Case ID Case Submitter ID  \
# 0    dae8930e-1fb8-11e9-b7f8-0a80fada099c         C3L-00791
# 1    bf7ade95-1fb8-11e9-b7f8-0a80fada099c         C3L-00360
# 2    b76d3749-1fb8-11e9-b7f8-0a80fada099c         C3L-00097
# 3    0e79bef5-1fba-11e9-b7f8-0a80fada099c               QC5
# 4    cc8a63fd-1fb8-11e9-b7f8-0a80fada099c         C3L-00583
# ..                                    ...               ...
# 203  cfd3d3fd-1fb8-11e9-b7f8-0a80fada099c         C3L-00607
# 204  a4300f90-1fb9-11e9-b7f8-0a80fada099c         C3N-01200
# 205  b9017fed-1fb8-11e9-b7f8-0a80fada099c         C3L-00103
# 206  0809987b-1fba-11e9-b7f8-0a80fada099c               QC1
# 207  14074e8f-1fb9-11e9-b7f8-0a80fada099c         C3L-01313
#
#                           Project Name          Sample Type  Primary Site  \
# 0    CPTAC3 Discovery and Confirmatory        Primary Tumor        Kidney
# 1    CPTAC3 Discovery and Confirmatory  Solid Tissue Normal        Kidney
# 2    CPTAC3 Discovery and Confirmatory  Solid Tissue Normal        Kidney
# 3    CPTAC3 Discovery and Confirmatory         Not Reported  Not Reported
# 4    CPTAC3 Discovery and Confirmatory        Primary Tumor        Kidney
# ..                                 ...                  ...           ...
# 203  CPTAC3 Discovery and Confirmatory  Solid Tissue Normal        Kidney
# 204  CPTAC3 Discovery and Confirmatory        Primary Tumor        Kidney
# 205  CPTAC3 Discovery and Confirmatory  Solid Tissue Normal        Kidney
# 206  CPTAC3 Discovery and Confirmatory         Not Reported  Not Reported
# 207  CPTAC3 Discovery and Confirmatory        Primary Tumor        Kidney
#
#                         Disease Type  ... Sample Ordinal Shortest Dimension  \
# 0    Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
# 1    Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
# 2    Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
# 3                              Other  ...            NaN                NaN
# 4    Clear Cell Renal Cell Carcinoma  ...            1.0                NaN
# ..                               ...  ...            ...                ...
# 203  Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
# 204  Clear Cell Renal Cell Carcinoma  ...            2.0                NaN
# 205  Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
# 206                            Other  ...            NaN                NaN
# 207  Clear Cell Renal Cell Carcinoma  ...            NaN                NaN
#
#      Time Between Clamping And Freezing  Time Between Excision and Freezing  \
# 0                                   NaN                                13.0
# 1                                   NaN                                20.0
# 2                                   NaN                                25.0
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
# ..                                  ...                                 ...
# 203                                 NaN                                19.0
# 204                                 NaN                                 NaN
# 205                                 NaN                                23.0
# 206                                 NaN                                 NaN
# 207                                 NaN                                21.0
#
#      Tissue Collection Type   Tissue Type  Tumor Code Tumor Code ID  \
# 0                       NaN         Tumor         NaN           NaN
# 1                       NaN        Normal         NaN           NaN
# 2                       NaN        Normal         NaN           NaN
# 3                       NaN  Not Reported         NaN           NaN
# 4                       NaN         Tumor         NaN           NaN
# ..                      ...           ...         ...           ...
# 203                     NaN        Normal         NaN           NaN
# 204                     NaN         Tumor         NaN           NaN
# 205                     NaN        Normal         NaN           NaN
# 206                     NaN  Not Reported         NaN           NaN
# 207                     NaN         Tumor         NaN           NaN
#
#     Tumor Descriptor                                  Program Name
# 0                NaN  Clinical Proteomic Tumor Analysis Consortium
# 1                NaN  Clinical Proteomic Tumor Analysis Consortium
# 2                NaN  Clinical Proteomic Tumor Analysis Consortium
# 3       Not Reported  Clinical Proteomic Tumor Analysis Consortium
# 4                NaN  Clinical Proteomic Tumor Analysis Consortium
# ..               ...                                           ...
# 203              NaN  Clinical Proteomic Tumor Analysis Consortium
# 204              NaN  Clinical Proteomic Tumor Analysis Consortium
# 205              NaN  Clinical Proteomic Tumor Analysis Consortium
# 206     Not Reported  Clinical Proteomic Tumor Analysis Consortium
# 207              NaN  Clinical Proteomic Tumor Analysis Consortium
#
# [208 rows x 44 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sciviso import *
from sciutil import SciUtil
import os
import seaborn as sns
# Have a look at clustering each of these
from sklearn.decomposition import PCA

OPP = ['#51AE66', '#AE5199', '#4325DA', '#BCDA25']

u = SciUtil()

disease = 'ClearCellRenalCellCarcinoma'

# Make a log file
output_dir = f'../../output_data/{disease}'

save_fig = True
plot_fig = True

fig_dir = f'../../output_data/{disease}/figs/'

logfile = os.path.join(output_dir, f'{disease}_Protein_filterlog.tsv')
logfile = open(logfile, 'w+')

# https://cptac-data-portal.georgetown.edu/cptac/documents/CDAP_Results_Overview_rev_09152014.pdf
disease = 'ClearCellRenalCellCarcinoma'
input_folder = '/Users/ariane/Documents/code/public_cancer_data/datasets/CPTAC3/input_data/ClearCellRenalCellCarcinoma_PDC000127'
filename = 'Clear_Cell_Renal_Cell_Carcinoma'

# Get the summary file and the biospecimen file
df = pd.read_csv(os.path.join(input_folder, f'CPTAC3_{filename}_Proteome.tmt10.tsv'), sep='\t')
sample_df = pd.read_csv(os.path.join(input_folder, f'PDC_study_biospecimen_07172023_114806.tsv'), sep='\t')
case_df = pd.read_csv(os.path.join(output_dir, f'{disease}_case.csv'))
sample_df['SafeCases'] = [c.replace('-', '.') for c in sample_df['Case Submitter ID'].values]
sample_df.set_index('SafeCases', inplace=True)
case_df.set_index('SafeCases', inplace=True)
sample_df = sample_df.join(case_df, how='left', lsuffix='_protein')


# ----------- Remove std row
gene_drop_columns = ['Mean', 'Median', 'StdDev']
df = df[~df['Gene'].isin(gene_drop_columns)]

plt.rcParams["figure.figsize"] = (20, 3)
cols = [c for c in df.columns if 'Log' in c and 'Unshared' not in c]
X = df[cols].values
df.boxplot(column=cols)
plt.xticks(rotation=90)
plt.show()

# Drop columns that dont have CPT in them
df = df[['Gene'] + [c for c in df.columns if 'CPT' in c and 'Unshared' not in c]]

# Drop outliers from each gene (this could affect the DA)
cols = [c for c in df.columns if 'Log' in c and 'Unshared' not in c]

df.boxplot(column=cols)
plt.xticks(rotation=90)
plt.show()

# Check the distribution
plt.rcParams["figure.figsize"] = (4, 3)
plt.hist(np.mean(df[cols].values, axis=1), bins=20)
plt.show()

# Set NaNs for values that are 2SD or greater from the mean of the gene
mean_protein = np.nanmean(df[cols].values, axis=1)
std_protein = np.nanstd(df[cols].values, axis=1)
print(mean_protein, std_protein)
upper_cutoff = mean_protein + (2 * std_protein)
lower_cutoff = mean_protein - (2 * std_protein)
for col in cols:
    df[col][df[col] > upper_cutoff] = None
    df[col][df[col] < lower_cutoff] = None
    
# Drop outliers from each gene (this could affect the DA)
cols = [c for c in df.columns if 'Log' in c and 'Unshared' not in c]
plt.rcParams["figure.figsize"] = (20, 3)

df.boxplot(column=cols)
plt.xticks(rotation=90)
plt.show()

plt.rcParams["figure.figsize"] = (20, 3)

df.boxplot(column=cols)
plt.xticks(rotation=90)
plt.show()

# Drop genes with > 25% missing values (including those with Nulls that we put in )
df = df[df.isnull().sum(axis=1) < len(df.values[0])/4]
df.shape
    

# -------------------------------------------
#       Rename the columns so that they are in the same format as the other data types
# -------------------------------------------
# C3L.00094_Tumor_RNA_LungAdenocarcinoma_167b35b1.7858.4b23.8b87.17c660b5d658 
col_map = {'Gene': 'gene_name'}
sample_types = sample_df['Sample Type'].values
sample_df['SafeCases'] = sample_df.index
submitter_ids = sample_df['SafeCases'].values
tumour_type = []
samples = []
cond_ids = []
for i, aliquot in enumerate(sample_df['Aliquot Submitter ID'].values):
    if sample_types[i] == 'Primary Tumor':
        sample_type = 'Tumor'
    elif sample_types[i] == 'Solid Tissue Normal':
        sample_type = 'Normal'
    else:
        print(sample_types[i])
        sample_type = 'NA'
    tumour_type.append(sample_type)
    col_map[f'{aliquot} Log Ratio'] = f'{submitter_ids[i]}_{sample_type}_Protein_{aliquot}'
    samples.append(f'{submitter_ids[i]}_{sample_type}_Protein_{aliquot}')
    cond_id = 0 if sample_type == 'Normal' else 1
    cond_ids.append(cond_id)
sample_df['Sample'] = samples
sample_df['CondID'] = cond_ids
sample_df['CondLabel'] = tumour_type

sample_df = sample_df[sample_df['CondLabel'] != 'NA']

df = df.rename(columns=col_map)
   
# -------------------------------------------
#       Compute correlation
# -------------------------------------------
cols = [c for c in df.columns if c != 'gene_name']

corr = df[cols].corr()

# Print out the minimum correlation:
mean_cor = np.nanmean(corr, axis=1)
corr['mean_corr'] = mean_cor
corr.sort_values(by=['mean_corr'])

m_corr = np.mean(mean_cor)
# Plot out the mean correlation values so we can choose a good filter.
h = Histogram(corr, x='mean_corr', title=f'Mean corr. {m_corr}')
if save_fig:
    plt.savefig(os.path.join(fig_dir, f'{disease}_Protein_corrHist.svg'))
if plot_fig:
    plt.show()

u.dp(['Mean corr: ', m_corr, 'std corr', np.std(mean_cor)])
logfile.write(f'Mean Pearsons correlation\t{m_corr}\n')
logfile.write(f'Std Pearsons correlation\t{np.std(mean_cor)}\n')

# -------------------------------------------
#       Filter patients on correlation
# -------------------------------------------
corr_sorted = corr.sort_values(by=['mean_corr'])
cutoff = np.mean(corr_sorted.mean_corr) - (1.5 * np.std(corr_sorted.mean_corr))
corr_sorted = corr_sorted[corr_sorted['mean_corr'] < cutoff]

u.dp(['Protein size after correlation filter: ', np.nanmean(corr_sorted.mean_corr), cutoff, df.shape])

cols_to_omit = [c for c in corr_sorted.index]

logfile.write(f'Protein columns to omit\t{",".join(cols_to_omit)}\n')
u.dp(['Protein columns to omit: '])
print('\n'.join(cols_to_omit))

cols_to_keep = [c for c in df.columns if c not in cols_to_omit]
df = df[cols_to_keep]

u.dp(['Protein shape after dropping columns:', df.shape])
logfile.write(f'Protein size after correlation filter\t{df.shape}\n')

# -------------------------------------------
#    Filter sample df to only include samples passing QC
# -------------------------------------------
sample_df = sample_df[sample_df['Sample'].isin(cols_to_keep)]

# -------------------------------------------
#    Visualise to check using PCA
# -------------------------------------------
cols = list(sample_df['Sample'].values)

vals = df[cols].values.T

# For vis replace Nan with mean - we'll impute later
vals = np.nan_to_num(vals, np.mean(np.mean(vals)))

pca = PCA(n_components=2)
pca_values = pca.fit_transform(vals)
var_ratio = pca.fit(vals).explained_variance_ratio_
plt.rcParams['figure.figsize'] = [4, 4]
vis_df = pd.DataFrame()
vis_df['PC_1'] = pca_values[:, 0]
vis_df['PC_2'] = pca_values[:, 1]
vis_df['Stage'] = sample_df['TumorStage'].values
vis_df['Disease'] = sample_df['Disease'].values
vis_df['CondID'] = sample_df['CondID'].values
vis_df['Colour'] = ['#C24B3D' if c == 1 else '#3DB4C2' for c in vis_df['CondID'].values]
stage_c_map = {'Stage I': '#3139ba', 'Stage II': '#7169E4', 'Stage III': '#2A9D8F',
               'Stage IV': '#264653'}
vis_df['StageColour'] = [stage_c_map.get(c) if stage_c_map.get(c) else '#808080' for c in vis_df['Stage'].values]
vis_df['Primary Site'] = sample_df['Primary Site'].values

sc = Scatterplot(vis_df, x='PC_1', y='PC_2', title=f'Sample Type', xlabel='PC 1', ylabel='PC 2',
                 add_legend=True, colour=vis_df['Colour'].values,
                 config={'s': 40, 'opacity': 0.6, 'figsize': (3, 3)})
sc.plot()
if save_fig:
    plt.savefig(os.path.join(fig_dir, f'{disease}_Protein_scatterPCASampleType.svg'))
if plot_fig:
    plt.show()

sc = Scatterplot(vis_df, x='PC_1', y='PC_2', title=f'Stage', xlabel='PC 1', ylabel='PC 2',
                 add_legend=True, colour=vis_df['StageColour'].values,
                 config={'s': 40, 'opacity': 0.6, 'figsize': (3, 3)})
sc.plot()
if save_fig:
    plt.savefig(os.path.join(fig_dir, f'{disease}_Protein_scatterPCAStage.svg'))
if plot_fig:
    plt.show()
    
sc = Scatterplot(vis_df, x='PC_1', y='PC_2', title=f'Primary Site', xlabel='PC 1', ylabel='PC 2',
                 add_legend=True, color_col='Primary Site',
                 config={'s': 40, 'opacity': 0.6, 'figsize': (3, 3)})
sc.plot()
if save_fig:
    plt.savefig(os.path.join(fig_dir, f'{disease}_Protein_scatterPCASite.svg'))
if plot_fig:
    plt.show()

# -------------------------------------------
# Drop duplicates based on the case ID and the condition type of samples
# -------------------------------------------
u.dp(['Before dropping duplicate samples for a patient', sample_df.shape])
sample_df_dedup = sample_df.drop_duplicates(subset=['SafeCases', 'CondID'])
u.dp(['After dropping duplicate samples for a patient', sample_df_dedup.shape])
logfile.write(f'After dropping duplicates from samples\t{sample_df_dedup.shape}\n')
logfile.write(
    f'Duplicate samples that were dropped\t{",".join([c for c in sample_df.Sample if c not in list(sample_df_dedup.Sample)])}\n')
u.dp(['Cases included in dataset', len(list(set(sample_df_dedup.SafeCases.values)))])

logfile.write(f'Cases included in dataset\t{",".join(list(set(sample_df_dedup.SafeCases.values)))}\n')

samples = list(sample_df_dedup['Sample'].values)


# Drop the outliers and shift the 0 to be real numbered so that we can have a proper logFC
df_min = min(df[samples].min())

for col in samples:
    df[col] = df[col].values + abs(df_min)

sample_df_dedup.to_csv(os.path.join(output_dir, f'{disease}_filtered_samples_Protein.csv'), index=False)
df[['gene_name'] + samples].to_csv(os.path.join(output_dir, f'{disease}_filtered_Protein.csv'), index=False)
# Out:
# [ 0.01338917 -0.12877674 -0.06377224 ...  0.07260435  0.04240776
#   0.05510777] [0.47390812 0.67970476 0.65366965 ... 0.3305908  0.13443747 0.24535095]
# Cell Lines
# Cell Lines
# Cell Lines
# Cell Lines
# Cell Lines
# Not Reported
# Not Reported
# Not Reported
# Not Reported
# Not Reported
# Not Reported
# Not Reported
# Not Reported
# Not Reported
# --------------------------------------------------------------------------------
#          Mean corr: 	0.10639469932158296	std corr	0.057978883583908014
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Protein size after correlation filter: 	0.010686629208728777	0.019426373945720943	(8673, 195)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                            Protein columns to omit:
# --------------------------------------------------------------------------------
# C3N.01522_Normal_Protein_CPT0077140001
# C3L.00791_Normal_Protein_CPT0026420001
# C3N.01179_Normal_Protein_CPT0088920001
# C3L.01885_Normal_Protein_CPT0092800003
# C3N.01651_Normal_Protein_CPT0088710001
# C3L.01603_Normal_Protein_CPT0087050003
# C3L.00447_Normal_Protein_CPT0006950001
# C3N.00148_Normal_Protein_CPT0081620001
# C3L.00561_Normal_Protein_CPT0023360001
# C3L.00011_Normal_Protein_CPT0001350001
# C3N.00953_Normal_Protein_CPT0065450001
# C3L.00097_Normal_Protein_CPT0000790001
# C3L.00088_Normal_Protein_CPT0000890001
# C3N.00495_Normal_Protein_CPT0078530001
# C3L.01861_Normal_Protein_CPT0092310003
# C3N.00320_Normal_Protein_CPT0013790003
# C3L.00418_Normal_Protein_CPT0006730001
# C3N.01261_Normal_Protein_CPT0077500001
# --------------------------------------------------------------------------------
#                Protein shape after dropping columns:	(8673, 177)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#           Before dropping duplicate samples for a patient	(176, 364)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#            After dropping duplicate samples for a patient	(176, 364)
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
#                          Cases included in dataset	110
# --------------------------------------------------------------------------------
